# %% [markdown]
# # 06 Error Analysis
# Review misclassified examples after evaluation. Likely causes to inspect: visually similar foliar diseases, low image quality, lighting shifts, leaf occlusion, and class imbalance.

# %%
from pathlib import Path

report = Path('../docs/model_performance_report.md')
print(report.read_text() if report.exists() else 'Run evaluation first.')

# %% [markdown]
# ## Notes
# - Compare confused pairs against symptoms that overlap visually.
# - Check whether the training distribution underrepresents minority classes.
# - Inspect field-like photos separately from lab-condition PlantVillage images.
