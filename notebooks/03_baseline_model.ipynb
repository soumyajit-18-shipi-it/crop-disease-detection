# %% [markdown]
# # 03 Baseline Model
# Run the shared training loop with the scratch CNN benchmark.

# %%
from src.training.train import train

# Create a temporary YAML with architecture: baseline_cnn, or edit configs/base.yaml.
best_checkpoint = train('../configs/base.yaml')
best_checkpoint
