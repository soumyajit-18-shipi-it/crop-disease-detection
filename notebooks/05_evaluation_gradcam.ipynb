# %% [markdown]
# # 05 Evaluation and Grad-CAM
# Evaluate a trained checkpoint and use Grad-CAM helpers for visual explanations.

# %%
from src.evaluation.evaluate import evaluate

report_path = evaluate('../models/checkpoints/best_model.pth')
report_path

# %%
# Example after selecting a target layer for your architecture:
# from src.evaluation.gradcam import generate_gradcam
# overlay = generate_gradcam(model, image_tensor, target_layer)
